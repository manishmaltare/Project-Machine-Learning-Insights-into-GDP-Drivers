# %% [markdown]
# # DATA LOADING

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/india1.xlsx')

# %%
df.head()
# Out:
#    Year  Natural disasters       Exports       Imports  \
# 0  1980            1183188  1.143974e+10  1.722613e+10
# 1  1981             837783  1.148570e+10  1.658461e+10
# 2  1982            4563958  1.200942e+10  1.634353e+10
# 3  1983            1808019  1.274134e+10  1.714005e+10
# 4  1984             372505  1.333072e+10  1.639125e+10
#
#   political leadership change type of leadership         FDI  Population  \
# 0               Indira Gandhi         Democratic  79159999.9   687354025
# 1               Indira Gandhi         Democratic  91920000.0   703696250
# 2               Indira Gandhi         Democratic  72079999.9   720313473
# 3               Indira Gandhi         Democratic   5639999.9   737372681
# 4                Rajiv Gandhi         Democratic  19239999.9   754875449
#
#   Wars fought in year  Investment in Defence year wise           GDP
# 0                  No                      11087705000  1.863286e+11
# 1                  No                      11706276000  1.934914e+11
# 2                  No                      12701485000  2.007156e+11
# 3                  No                      13144250000  2.182621e+11
# 4                  No                      13904538000  2.121576e+11

# %%
df.shape
# Out:
# (45, 11)

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             45 non-null     int64
#  1   Natural disasters                45 non-null     int64
#  2   Exports                          45 non-null     float64
#  3   Imports                          45 non-null     float64
#  4   political leadership change      45 non-null     object
#  5   type of leadership               45 non-null     object
#  6   FDI                              45 non-null     float64
#  7   Population                       45 non-null     int64
#  8   Wars fought in year              45 non-null     object
#  9   Investment in Defence year wise  45 non-null     int64
#  10  GDP                              45 non-null     float64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 4.0+ KB

# %%
df.isnull().sum()
# Out:
# Year                               0
# Natural disasters                  0
# Exports                            0
# Imports                            0
# political leadership change        0
# type of leadership                 0
# FDI                                0
# Population                         0
# Wars fought in year                0
# Investment in Defence year wise    0
# GDP                                0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Natural disasters       Exports       Imports  \
# count    45.000000       4.500000e+01  4.500000e+01  4.500000e+01
# mean   2002.000000       4.731238e+06  2.285065e+11  2.620712e+11
# std      13.133926       6.755619e+06  2.509688e+11  2.854550e+11
# min    1980.000000       0.000000e+00  1.143974e+10  1.634353e+10
# 25%    1991.000000       7.114610e+05  2.294340e+10  2.713207e+10
# 50%    2002.000000       2.658254e+06  7.345290e+10  7.849876e+10
# 75%    2013.000000       5.136550e+06  4.473844e+11  5.102447e+11
# max    2024.000000       3.111638e+07  8.286335e+11  9.192062e+11
#
#                 FDI    Population  Investment in Defence year wise  \
# count  4.500000e+01  4.500000e+01                     4.500000e+01
# mean   1.682569e+10  1.087030e+09                     3.999122e+10
# std    1.926322e+10  2.371413e+08                     2.297406e+10
# min    5.640000e+06  6.873540e+08                     1.108770e+10
# 25%    2.521000e+08  8.839276e+08                     2.110819e+10
# 50%    5.128094e+09  1.097600e+09                     3.211731e+10
# 75%    3.457664e+10  1.295830e+09                     5.586206e+10
# max    6.436236e+10  1.450936e+09                     8.362314e+10
#
#                 GDP
# count  4.500000e+01
# mean   1.172288e+12
# std    1.107472e+12
# min    1.863286e+11
# 25%    2.960421e+11
# 50%    5.149391e+11
# 75%    1.856722e+12
# max    3.912686e+12

# %%
df.set_index('Year', inplace=True)

# %%
df.head(4)
# Out:
#       Natural disasters       Exports       Imports  \
# Year
# 1980            1183188  1.143974e+10  1.722613e+10
# 1981             837783  1.148570e+10  1.658461e+10
# 1982            4563958  1.200942e+10  1.634353e+10
# 1983            1808019  1.274134e+10  1.714005e+10
#
#      political leadership change type of leadership         FDI  Population  \
# Year
# 1980               Indira Gandhi         Democratic  79159999.9   687354025
# 1981               Indira Gandhi         Democratic  91920000.0   703696250
# 1982               Indira Gandhi         Democratic  72079999.9   720313473
# 1983               Indira Gandhi         Democratic   5639999.9   737372681
#
#      Wars fought in year  Investment in Defence year wise           GDP
# Year
# 1980                  No                      11087705000  1.863286e+11
# 1981                  No                      11706276000  1.934914e+11
# 1982                  No                      12701485000  2.007156e+11
# 1983                  No                      13144250000  2.182621e+11

# %%
df.isnull().sum()
# Out:
# Natural disasters                  0
# Exports                            0
# Imports                            0
# political leadership change        0
# type of leadership                 0
# FDI                                0
# Population                         0
# Wars fought in year                0
# Investment in Defence year wise    0
# GDP                                0
# dtype: int64

# %%
df.nunique()
# Out:
# Natural disasters                  44
# Exports                            45
# Imports                            45
# political leadership change         9
# type of leadership                  1
# FDI                                45
# Population                         45
# Wars fought in year                 2
# Investment in Defence year wise    45
# GDP                                45
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Natural disasters                  44
# Exports                            45
# Imports                            45
# political leadership change         9
# type of leadership                  1
# FDI                                45
# Population                         45
# Wars fought in year                 2
# Investment in Defence year wise    45
# GDP                                45
# dtype: int64

# %%
df.columns
# Out:
# Index(['Natural disasters', 'Exports', 'Imports',
#        'political leadership change', 'type of leadership', 'FDI',
#        'Population', 'Wars fought in year', 'Investment in Defence year wise',
#        'GDP'],
#       dtype='object')

# %%
df.rename(columns={'Natural disasters': 'Natural_disasters',
       'political leadership change' :'political_leadership_change' , 'type of leadership': 'type_of_government',
       'Wars fought in year' : 'Wars_fought_in_year', 'Investment in Defence year wise':'Investment_in_Defence_year_wise'}, inplace=True)

# %%
df.head(3)
# Out:
#       Natural_disasters       Exports       Imports  \
# Year
# 1980            1183188  1.143974e+10  1.722613e+10
# 1981             837783  1.148570e+10  1.658461e+10
# 1982            4563958  1.200942e+10  1.634353e+10
#
#      political_leadership_change type_of_government         FDI  Population  \
# Year
# 1980               Indira Gandhi         Democratic  79159999.9   687354025
# 1981               Indira Gandhi         Democratic  91920000.0   703696250
# 1982               Indira Gandhi         Democratic  72079999.9   720313473
#
#      Wars_fought_in_year  Investment_in_Defence_year_wise           GDP
# Year
# 1980                  No                      11087705000  1.863286e+11
# 1981                  No                      11706276000  1.934914e+11
# 1982                  No                      12701485000  2.007156e+11

# %%
df.corr(numeric_only=True)
# Out:
#                                  Natural_disasters   Exports   Imports  \
# Natural_disasters                         1.000000  0.258557  0.235038
# Exports                                   0.258557  1.000000  0.997710
# Imports                                   0.235038  0.997710  1.000000
# FDI                                       0.434387  0.863458  0.864193
# Population                                0.333257  0.900010  0.897829
# Investment_in_Defence_year_wise           0.342828  0.967523  0.963459
# GDP                                       0.284453  0.991165  0.984220
#
#                                       FDI  Population  \
# Natural_disasters                0.434387    0.333257
# Exports                          0.863458    0.900010
# Imports                          0.864193    0.897829
# FDI                              1.000000    0.867999
# Population                       0.867999    1.000000
# Investment_in_Defence_year_wise  0.910480    0.963265
# GDP                              0.868211    0.898853
#
#                                  Investment_in_Defence_year_wise       GDP
# Natural_disasters                                       0.342828  0.284453
# Exports                                                 0.967523  0.991165
# Imports                                                 0.963459  0.984220
# FDI                                                     0.910480  0.868211
# Population                                              0.963265  0.898853
# Investment_in_Defence_year_wise                         1.000000  0.974559
# GDP                                                     0.974559  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# This visualization shows that the variables are
# highly multicollinear, SO we can't use the MLR
# method here.
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
i=df.columns
i
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
def regplot(obj,l):
  i=obj.columns
  for i in obj:
    sns.regplot(x=obj[i], y=l)
    plt.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
df.drop('type_of_government', axis=1, inplace=True)

# %%
df.head(4)
# Out:
#       Natural_disasters       Exports       Imports  \
# Year
# 1980            1183188  1.143974e+10  1.722613e+10
# 1981             837783  1.148570e+10  1.658461e+10
# 1982            4563958  1.200942e+10  1.634353e+10
# 1983            1808019  1.274134e+10  1.714005e+10
#
#      political_leadership_change         FDI  Population Wars_fought_in_year  \
# Year
# 1980               Indira Gandhi  79159999.9   687354025                  No
# 1981               Indira Gandhi  91920000.0   703696250                  No
# 1982               Indira Gandhi  72079999.9   720313473                  No
# 1983               Indira Gandhi   5639999.9   737372681                  No
#
#       Investment_in_Defence_year_wise           GDP
# Year
# 1980                      11087705000  1.863286e+11
# 1981                      11706276000  1.934914e+11
# 1982                      12701485000  2.007156e+11
# 1983                      13144250000  2.182621e+11

# %%
df = pd.get_dummies(df,drop_first=False)

# %%
df.nunique()
# Out:
# Natural_disasters                                   44
# Exports                                             45
# Imports                                             45
# FDI                                                 45
# Population                                          45
# Investment_in_Defence_year_wise                     45
# GDP                                                 45
# political_leadership_change_Atal Bihari Vajpayee     2
# political_leadership_change_Chandra Shekhar          2
# political_leadership_change_H. D. Deve Gowda         2
# political_leadership_change_Inder Kumar Gujral       2
# political_leadership_change_Indira Gandhi            2
# political_leadership_change_Manmohan Singh           2
# political_leadership_change_Narendra Modi            2
# political_leadership_change_P. V. Narasimha Rao      2
# political_leadership_change_Rajiv Gandhi             2
# Wars_fought_in_year_No                               2
# Wars_fought_in_year_Yes                              2
# dtype: int64

# %%
df.head(2)
# Out:
#       Natural_disasters       Exports       Imports         FDI  Population  \
# Year
# 1980            1183188  1.143974e+10  1.722613e+10  79159999.9   687354025
# 1981             837783  1.148570e+10  1.658461e+10  91920000.0   703696250
#
#       Investment_in_Defence_year_wise           GDP  \
# Year
# 1980                      11087705000  1.863286e+11
# 1981                      11706276000  1.934914e+11
#
#       political_leadership_change_Atal Bihari Vajpayee  \
# Year
# 1980                                             False
# 1981                                             False
#
#       political_leadership_change_Chandra Shekhar  \
# Year
# 1980                                        False
# 1981                                        False
#
#       political_leadership_change_H. D. Deve Gowda  \
# Year
# 1980                                         False
# 1981                                         False
#
#       political_leadership_change_Inder Kumar Gujral  \
# Year
# 1980                                           False
# 1981                                           False
#
#       political_leadership_change_Indira Gandhi  \
# Year
# 1980                                       True
# 1981                                       True
#
#       political_leadership_change_Manmohan Singh  \
# Year
# 1980                                       False
# 1981                                       False
#
#       political_leadership_change_Narendra Modi  \
# Year
# 1980                                      False
# 1981                                      False
#
#       political_leadership_change_P. V. Narasimha Rao  \
# Year
# 1980                                            False
# 1981                                            False
#
#       political_leadership_change_Rajiv Gandhi  Wars_fought_in_year_No  \
# Year
# 1980                                     False                    True
# 1981                                     False                    True
#
#       Wars_fought_in_year_Yes
# Year
# 1980                    False
# 1981                    False

# %%
def boxplot(obj):
  i = obj.columns
  for i in obj:
    sns.boxplot(df[i])
    plt.tight_layout()
    plt.show()

# %%
boxplot(df)
# This visualization shows that only "Natural Disasters"
# have some outliers, most of the variables dont have outliers,
# the remaining are dummy variables.

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports', 'FDI', 'Population',
#        'Investment_in_Defence_year_wise', 'GDP',
#        'political_leadership_change_Atal Bihari Vajpayee',
#        'political_leadership_change_Chandra Shekhar',
#        'political_leadership_change_H. D. Deve Gowda',
#        'political_leadership_change_Inder Kumar Gujral',
#        'political_leadership_change_Indira Gandhi',
#        'political_leadership_change_Manmohan Singh',
#        'political_leadership_change_Narendra Modi',
#        'political_leadership_change_P. V. Narasimha Rao',
#        'political_leadership_change_Rajiv Gandhi', 'Wars_fought_in_year_No',
#        'Wars_fought_in_year_Yes'],
#       dtype='object')

# %%
x = df.drop(['GDP'],axis=1)

# %%
x.head(2)
# Out:
#       Natural_disasters       Exports       Imports         FDI  Population  \
# Year
# 1980            1183188  1.143974e+10  1.722613e+10  79159999.9   687354025
# 1981             837783  1.148570e+10  1.658461e+10  91920000.0   703696250
#
#       Investment_in_Defence_year_wise  \
# Year
# 1980                      11087705000
# 1981                      11706276000
#
#       political_leadership_change_Atal Bihari Vajpayee  \
# Year
# 1980                                             False
# 1981                                             False
#
#       political_leadership_change_Chandra Shekhar  \
# Year
# 1980                                        False
# 1981                                        False
#
#       political_leadership_change_H. D. Deve Gowda  \
# Year
# 1980                                         False
# 1981                                         False
#
#       political_leadership_change_Inder Kumar Gujral  \
# Year
# 1980                                           False
# 1981                                           False
#
#       political_leadership_change_Indira Gandhi  \
# Year
# 1980                                       True
# 1981                                       True
#
#       political_leadership_change_Manmohan Singh  \
# Year
# 1980                                       False
# 1981                                       False
#
#       political_leadership_change_Narendra Modi  \
# Year
# 1980                                      False
# 1981                                      False
#
#       political_leadership_change_P. V. Narasimha Rao  \
# Year
# 1980                                            False
# 1981                                            False
#
#       political_leadership_change_Rajiv Gandhi  Wars_fought_in_year_No  \
# Year
# 1980                                     False                    True
# 1981                                     False                    True
#
#       Wars_fought_in_year_Yes
# Year
# 1980                    False
# 1981                    False

# %%
y=df['GDP']

# %%
# Applying the ML algorithms
from sklearn.model_selection import GridSearchCV, train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42, train_size=0.7)

# %% [markdown]
# # DECISION TREE

# %% [markdown]
# ### Training Dataset

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree_train= DecisionTreeRegressor()

# %%
model_dtree_train = dtree_train.fit(x_train,y_train)

# %%
y_pred_train = model_dtree_train.predict(x_train)

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
r2_score_train=r2_score(y_pred_train, y_train)

print(f"R2-score : {r2_score_train}")
# Out:
# R2-score : 1.0

# %% [markdown]
# ### Testing Dataset

# %%
dtree_test= DecisionTreeRegressor()

# %%
model_dtree_test = dtree_test.fit(x_test,y_test)

# %%
y_pred_test = model_dtree_test.predict(x_test)

# %% [markdown]
# ### Evaluation

# %%
r2_score_test=r2_score(y_pred_test, y_test)

print(f"R2-score : {r2_score_test}")
# Out:
# R2-score : 1.0

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# ### Training Dataset

# %%
# I am doing Hyperparameter Tuning also.

# %%
param_grid = {'criterion': ['squared_error','friedman_mse','absolute_error','poisson'],'max_depth': [1,2, 3, 4, 5, None],'min_samples_split': [1,2, 5, 10],'min_samples_leaf': [1, 2, 4]}

# %%
# Training the Model : 80% data

# %%
dtree1= DecisionTreeRegressor(criterion='squared_error',max_depth=2,min_samples_leaf=1,min_samples_split=2,random_state = 42)
# applied the Best Hyperparameter, as per the GridSearchCV given below.

# %%
dtree1.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
grid_search_train = GridSearchCV(estimator=dtree1, param_grid=param_grid, n_jobs=1,cv=5)
grid_search_train.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 360 fits failed out of a total of 1440.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       n
_jobs=1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [1, 2, 5, 10]})

# %%
grid_search_train.best_params_ # The best parameters.
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
dtree1= DecisionTreeRegressor(criterion='squared_error',max_depth=5,min_samples_leaf=1,min_samples_split=2, random_state = 42)
# applied the Best Hyperparameter, as per the GridSearchCV given above.

# %%
dtree1.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
y_pred_train_tuned = dtree1.predict(x_train)

# %% [markdown]
# ### Testing Dataset

# %%
# I am doing Hyperparameter Tuning also.

# %%
param_grid = {'criterion': ['squared_error','friedman_mse','absolute_error','poisson'],'max_depth': [1,2, 3, 4, 5, None],'min_samples_split': [1,2, 5, 10],'min_samples_leaf': [1, 2, 4]}

# %%
# Training the Model : 80% data

# %%
dtree2= DecisionTreeRegressor(criterion='squared_error',max_depth=2,min_samples_leaf=1,min_samples_split=2, random_state = 42)
# applied the Best Hyperparameter, as per the GridSearchCV given below.

# %%
dtree2.fit(x_test, y_test)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
grid_search_test = GridSearchCV(estimator=dtree2, param_grid=param_grid, n_jobs=1,cv=5)
grid_search_test.fit(x_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 360 fits failed out of a total of 1440.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [            nan -1.26606106e+01 -1.26606106e+01 -1.26606106e+01
#              nan -1.26606106e+01 -1.26606106e+01 -1.26606106e+01
#              nan -1.33655560e+01 -1.33655560e+01 -1.33655560e+01
#              nan  2.13216939e-01 -1.98395719e-01 -1.26606106e+01
#              nan -4.73902117e-02 -1.98395719e-01 -1.26606106e+01
#              nan -1.33771102e+01 -1.33771102e+01 -1.33655560e+01
#              nan  3.60096831e-01 -1.95250736e-01 -1.26606106e+01
#              nan -8.20914522e-02 -1.95250736e-01 -1.26606106e+01
#              nan -1.33771102e+01 -1.33771102e+01 -1.33655560e+01
#              nan  5.25858484e-01 -1.95250736e-01 -1.26606106e+01
#              nan -8.20914522e-02 -1.95250736e-01 -1.26606106e+01
#              nan -1.33771102e+01 -1.33771102e+01 -1.33655560e+01
#              nan  5.58676277e-01 -1.95250736e-01 -1.26606106e+01
#              nan -8.20914522e-02 -1.95250736e-01 -1.26606106e+01
#              nan -1.33771102e+01 -1.33771102e+01 -1.33655560e+01
#              nan  5.58676277e-01 -1.95250736e-01 -1.26606106e+01
#              nan -8.20914522e-02 -1.95250736e-01 -1.26606106e+01
#              nan -1.33771102e+01 -1.33771102e+01 -1.33655560e+01
#              nan -1.26606106e+01 -1.26606106e+01 -1.26606106e+01
#              nan -1.26606106e+01 -1.26606106e+01 -1.26606106e+01
#              nan -1.33655560e+01 -1.33655560e+01 -1.33655560e+01
#              nan  2.13216939e-01 -1.98395719e-01 -1.26606106e+01
#              nan -4.89151758e-01 -1.98395719e-01 -1.26606106e+01
#              nan -1.33771102e+01 -1.33771102e+01 -1.33655560e+01
#              nan  3.60096831e-01 -1.95250736e-01 -1.26606106e+01
#              nan -5.23852999e-01 -1.95250736e-01 -1.26606106e+01
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=DecisionTreeRegressor(max_depth=2, random_state=42),
#              n_jobs=1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [1, 2, 5, 10]})

# %%
grid_search_test.best_params_ # The best parameters.
# Out:
# {'criterion': 'absolute_error',
#  'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
dtree2= DecisionTreeRegressor(criterion='absolute_error',max_depth=None,min_samples_leaf=1,min_samples_split=2,random_state = 42)
# applied the Best Hyperparameter, as per the GridSearchCV given below.

# %%
from sklearn import tree

# %%
x_train_col= x_train.columns

# %%
dtree2.fit(x_test,y_test)
# Out:
# DecisionTreeRegressor(criterion='absolute_error', random_state=42)

# %%
y_pred_test_tuned = dtree2.predict(x_test)

# %% [markdown]
# ## Evaluation - Tuned Dataset

# %%
r2_score_train_tuned=r2_score(y_pred_train_tuned, y_train)

print(f"R2-score - Train - Tuned dataset : {r2_score_train_tuned:.5f}")


r2_score_test_tuned=r2_score(y_pred_test_tuned, y_test)

print(f"R2-score - Test - Tuned dataset : {r2_score_test_tuned:.6f}")
# Out:
# R2-score - Train - Tuned dataset : 0.99989
# R2-score - Test - Tuned dataset : 1.000000

# %% [markdown]
# ## Model building & Tree visualization

# %%
dtree1.fit(x_train, y_train)
plt.figure(figsize=(30,30))
tree.plot_tree(dtree1, feature_names=x_train_col)
plt.show()
# The Tree for training data is given below:-

# %%
x_train.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports', 'FDI', 'Population',
#        'Investment_in_Defence_year_wise',
#        'political_leadership_change_Atal Bihari Vajpayee',
#        'political_leadership_change_Chandra Shekhar',
#        'political_leadership_change_H. D. Deve Gowda',
#        'political_leadership_change_Inder Kumar Gujral',
#        'political_leadership_change_Indira Gandhi',
#        'political_leadership_change_Manmohan Singh',
#        'political_leadership_change_Narendra Modi',
#        'political_leadership_change_P. V. Narasimha Rao',
#        'political_leadership_change_Rajiv Gandhi', 'Wars_fought_in_year_No',
#        'Wars_fought_in_year_Yes'],
#       dtype='object')

# %% [markdown]
# ## Significant features

# %%
# Get feature names and importance
features = dtree1.feature_names_in_
importances = dtree1.feature_importances_

for name, score in zip(features, importances):
    print(f"{name}: {score:.5f}")
# Out:
# Natural_disasters: 0.00035
# Exports: 0.89576
# Imports: 0.06161
# FDI: 0.03097
# Population: 0.00012
# Investment_in_Defence_year_wise: 0.00980
# political_leadership_change_Atal Bihari Vajpayee: 0.00000
# political_leadership_change_Chandra Shekhar: 0.00000
# political_leadership_change_H. D. Deve Gowda: 0.00000
# political_leadership_change_Inder Kumar Gujral: 0.00000
# political_leadership_change_Indira Gandhi: 0.00000
# political_leadership_change_Manmohan Singh: 0.00140
# political_leadership_change_Narendra Modi: 0.00000
# political_leadership_change_P. V. Narasimha Rao: 0.00000
# political_leadership_change_Rajiv Gandhi: 0.00000
# Wars_fought_in_year_No: 0.00000
# Wars_fought_in_year_Yes: 0.00000
