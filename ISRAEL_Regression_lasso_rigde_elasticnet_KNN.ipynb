# %% [markdown]
# # DATA LOADING

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/israel1.xlsx',sheet_name = 'Sheet1')

# %%
df.head()
# Out:
#    Year  Natural disasters       Exports       Imports  \
# 0  1980                NaN  8.875098e+09  1.143471e+10
# 1  1981                NaN  9.097719e+09  1.222895e+10
# 2  1982                NaN  8.537572e+09  1.172626e+10
# 3  1983                NaN  8.754929e+09  1.201441e+10
# 4  1984                NaN  9.523963e+09  1.201263e+10
#
#   political leadership change type of leadership        FDI  Population  \
# 0              Menachem Begin         Democratic   51000000     3878000
# 1              Menachem Begin         Democratic  114400000     3956000
# 2              Menachem Begin         Democratic   21300000     4031000
# 3              Yitzḥak Shamir         Democratic   78500000     4105000
# 4                Shimon Peres         Democratic   89500000     4159000
#
#   Wars fought in year  Investment in Defence year wise           GDP
# 0                  No                      13685349000  2.539526e+10
# 1                  No                      16059739000  2.688201e+10
# 2                 Yes                      14874069000  2.925529e+10
# 3                  No                      13241298000  3.267576e+10
# 4                  No                      14401819000  3.064561e+10

# %%
df.shape
# Out:
# (45, 11)

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             45 non-null     int64
#  1   Natural disasters                8 non-null      float64
#  2   Exports                          45 non-null     float64
#  3   Imports                          45 non-null     float64
#  4   political leadership change      45 non-null     object
#  5   type of leadership               45 non-null     object
#  6   FDI                              45 non-null     int64
#  7   Population                       45 non-null     int64
#  8   Wars fought in year              45 non-null     object
#  9   Investment in Defence year wise  45 non-null     int64
#  10  GDP                              45 non-null     float64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 4.0+ KB

# %%
df.set_index('Year', inplace=True)

# %%
df.columns
# Out:
# Index(['Natural disasters', 'Exports', 'Imports',
#        'political leadership change', 'type of leadership', 'FDI',
#        'Population', 'Wars fought in year', 'Investment in Defence year wise',
#        'GDP'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Natural disasters       Exports       Imports           FDI  \
# count       8.000000e+00  4.500000e+01  4.500000e+01  4.500000e+01
# mean        4.028255e+05  5.854296e+10  5.843426e+10  6.480249e+09
# std         4.149782e+05  4.576767e+10  4.066474e+10  7.122325e+09
# min         4.866000e+03  8.537572e+09  1.143471e+10  2.130000e+07
# 25%         8.646825e+04  1.733152e+10  2.253411e+10  3.456000e+08
# 50%         2.572390e+05  4.295639e+10  4.493219e+10  3.322000e+09
# 75%         6.658355e+05  9.365633e+10  9.290624e+10  1.133620e+10
# max         1.194341e+06  1.648298e+11  1.536655e+11  2.288350e+10
#
#          Population  Investment in Defence year wise           GDP
# count  4.500000e+01                     4.500000e+01  4.500000e+01
# mean   6.587216e+06                     1.692121e+10  1.897981e+11
# std    1.858231e+06                     5.549089e+09  1.513411e+11
# min    3.878000e+06                     1.234735e+10  2.539526e+10
# 25%    4.949000e+06                     1.359914e+10  7.099876e+10
# 50%    6.570000e+06                     1.489690e+10  1.350020e+11
# 75%    8.059500e+06                     1.771492e+10  2.984781e+11
# max    9.974400e+06                     4.526712e+10  5.403799e+11

# %%
df.head(4)
# Out:
#       Natural disasters       Exports       Imports  \
# Year
# 1980                NaN  8.875098e+09  1.143471e+10
# 1981                NaN  9.097719e+09  1.222895e+10
# 1982                NaN  8.537572e+09  1.172626e+10
# 1983                NaN  8.754929e+09  1.201441e+10
#
#      political leadership change type of leadership        FDI  Population  \
# Year
# 1980              Menachem Begin         Democratic   51000000     3878000
# 1981              Menachem Begin         Democratic  114400000     3956000
# 1982              Menachem Begin         Democratic   21300000     4031000
# 1983              Yitzḥak Shamir         Democratic   78500000     4105000
#
#      Wars fought in year  Investment in Defence year wise           GDP
# Year
# 1980                  No                      13685349000  2.539526e+10
# 1981                  No                      16059739000  2.688201e+10
# 1982                 Yes                      14874069000  2.925529e+10
# 1983                  No                      13241298000  3.267576e+10

# %%
df.isnull().sum()
# Out:
# Natural disasters                  37
# Exports                             0
# Imports                             0
# political leadership change         0
# type of leadership                  0
# FDI                                 0
# Population                          0
# Wars fought in year                 0
# Investment in Defence year wise     0
# GDP                                 0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull()
# Out:
#       Natural disasters  Exports  Imports  political leadership change  \
# Year
# 1980              False    False    False                        False
# 1981              False    False    False                        False
# 1982              False    False    False                        False
# 1983              False    False    False                        False
# 1984              False    False    False                        False
# 1985              False    False    False                        False
# 1986              False    False    False                        False
# 1987              False    False    False                        False
# 1988              False    False    False                        False
# 1989              False    False    False                        False
# 1990              False    False    False                        False
# 1991              False    False    False                        False
# 1992              False    False    False                        False
# 1993              False    False    False                        False
# 1994              False    False    False                        False
# 1995              False    False    False                        False
# 1996              False    False    False                        False
# 1997              False    False    False                        False
# 1998              False    False    False                        False
# 1999              False    False    False                        False
# 2000              False    False    False                        False
# 2001              False    False    False                        False
# 2002              False    False    False                        False
# 2003              False    False    False                        False
# 2004              False    False    False                        False
# 2005              False    False    False                        False
# 2006              False    False    False                        False
# 2007              False    False    False                        False
# 2008              False    False    False                        False
# 2009              False    False    False                        False
# 2010              False    False    False                        False
# 2011              False    False    False                        False
# 2012              False    False    False                        False
# 2013              False    False    False                        False
# 2014              False    False    False                        False
# 2015              False    False    False                        False
# 2016              False    False    False                        False
# 2017              False    False    False                        False
# 2018              False    False    False                        False
# 2019              False    False    False                        False
# 2020              False    False    False                        False
# 2021              False    False    False                        False
# 2022              False    False    False                        False
# 2023              False    False    False                        False
# 2024              False    False    False                        False
#
#       type of leadership    FDI  Population  Wars fought in year  \
# Year
# 1980               False  False       False                False
# 1981               False  False       False                False
# 1982               False  False       False                False
# 1983               False  False       False                False
# 1984               False  False       False                False
# 1985               False  False       False                False
# 1986               False  False       False                False
# 1987               False  False       False                False
# 1988               False  False       False                False
# 1989               False  False       False                False
# 1990               False  False       False                False
# 1991               False  False       False                False
# 1992               False  False       False                False
# 1993               False  False       False                False
# 1994               False  False       False                False
# 1995               False  False       False                False
# 1996               False  False       False                False
# 1997               False  False       False                False
# 1998               False  False       False                False
# 1999               False  False       False                False
# 2000               False  False       False                False
# 2001               False  False       False                False
# 2002               False  False       False                False
# 2003               False  False       False                False
# 2004               False  False       False                False
# 2005               False  False       False                False
# 2006               False  False       False                False
# 2007               False  False       False                False
# 2008               False  False       False                False
# 2009               False  False       False                False
# 2010               False  False       False                False
# 2011               False  False       False                False
# 2012               False  False       False                False
# 2013               False  False       False                False
# 2014               False  False       False                False
# 2015               False  False       False                False
# 2016               False  False       False                False
# 2017               False  False       False                False
# 2018               False  False       False                False
# 2019               False  False       False                False
# 2020               False  False       False                False
# 2021               False  False       False                False
# 2022               False  False       False                False
# 2023               False  False       False                False
# 2024               False  False       False                False
#
#       Investment in Defence year wise    GDP
# Year
# 1980                            False  False
# 1981                            False  False
# 1982                            False  False
# 1983                            False  False
# 1984                            False  False
# 1985                            False  False
# 1986                            False  False
# 1987                            False  False
# 1988                            False  False
# 1989                            False  False
# 1990                            False  False
# 1991                            False  False
# 1992                            False  False
# 1993                            False  False
# 1994                            False  False
# 1995                            False  False
# 1996                            False  False
# 1997                            False  False
# 1998                            False  False
# 1999                            False  False
# 2000                            False  False
# 2001                            False  False
# 2002                            False  False
# 2003                            False  False
# 2004                            False  False
# 2005                            False  False
# 2006                            False  False
# 2007                            False  False
# 2008                            False  False
# 2009                            False  False
# 2010                            False  False
# 2011                            False  False
# 2012                            False  False
# 2013                            False  False
# 2014                            False  False
# 2015                            False  False
# 2016                            False  False
# 2017                            False  False
# 2018                            False  False
# 2019                            False  False
# 2020                            False  False
# 2021                            False  False
# 2022                            False  False
# 2023                            False  False
# 2024                            False  False

# %%
df.nunique()
# Out:
# Natural disasters                   9
# Exports                            45
# Imports                            45
# political leadership change        10
# type of leadership                  1
# FDI                                45
# Population                         45
# Wars fought in year                 2
# Investment in Defence year wise    45
# GDP                                45
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Natural disasters', 'Exports', 'Imports',
#        'political leadership change', 'type of leadership', 'FDI',
#        'Population', 'Wars fought in year', 'Investment in Defence year wise',
#        'GDP'],
#       dtype='object')

# %%
df.rename(columns={'Natural disasters': 'Natural_disasters',
       'political leadership change' :'political_leadership_change' , 'type of leadership': 'type_of_government',
       'Wars fought in year' : 'Wars_fought_in_year', 'Investment in Defence year wise':'Investment_in_Defence_year_wise'}, inplace=True)

# %%
df.head(3)
# Out:
#       Natural_disasters       Exports       Imports  \
# Year
# 1980                0.0  8.875098e+09  1.143471e+10
# 1981                0.0  9.097719e+09  1.222895e+10
# 1982                0.0  8.537572e+09  1.172626e+10
#
#      political_leadership_change type_of_government        FDI  Population  \
# Year
# 1980              Menachem Begin         Democratic   51000000     3878000
# 1981              Menachem Begin         Democratic  114400000     3956000
# 1982              Menachem Begin         Democratic   21300000     4031000
#
#      Wars_fought_in_year  Investment_in_Defence_year_wise           GDP
# Year
# 1980                  No                      13685349000  2.539526e+10
# 1981                  No                      16059739000  2.688201e+10
# 1982                 Yes                      14874069000  2.925529e+10

# %%
z=df.corr(numeric_only=True)

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# This visualization shows that the variables are
# highly multicollinear, SO we can't use the MLR
# method here.
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
i=df.columns
i
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
def regplot(obj,l):
  i=obj.columns
  for i in obj:
    sns.regplot(x=obj[i], y=l)
    plt.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
df.drop(['type_of_government'], axis=1, inplace=True)

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.nunique()
# Out:
# Natural_disasters                                  9
# Exports                                           45
# Imports                                           45
# FDI                                               45
# Population                                        45
# Investment_in_Defence_year_wise                   45
# GDP                                               45
# political_leadership_change_Benjamin Netanyahu     2
# political_leadership_change_Ehud Barak             2
# political_leadership_change_Ehud Olmert            2
# political_leadership_change_Menachem Begin         2
# political_leadership_change_Naftali Bennett        2
# political_leadership_change_Shimon Peres           2
# political_leadership_change_Yair Lapid             2
# political_leadership_change_Yitzhak Rabin          2
# political_leadership_change_Yitzḥak Shamir         2
# Wars_fought_in_year_Yes                            2
# dtype: int64

# %%
df.head(2)
# Out:
#       Natural_disasters       Exports       Imports        FDI  Population  \
# Year
# 1980                0.0  8.875098e+09  1.143471e+10   51000000     3878000
# 1981                0.0  9.097719e+09  1.222895e+10  114400000     3956000
#
#       Investment_in_Defence_year_wise           GDP  \
# Year
# 1980                      13685349000  2.539526e+10
# 1981                      16059739000  2.688201e+10
#
#       political_leadership_change_Benjamin Netanyahu  \
# Year
# 1980                                           False
# 1981                                           False
#
#       political_leadership_change_Ehud Barak  \
# Year
# 1980                                   False
# 1981                                   False
#
#       political_leadership_change_Ehud Olmert  \
# Year
# 1980                                    False
# 1981                                    False
#
#       political_leadership_change_Menachem Begin  \
# Year
# 1980                                        True
# 1981                                        True
#
#       political_leadership_change_Naftali Bennett  \
# Year
# 1980                                        False
# 1981                                        False
#
#       political_leadership_change_Shimon Peres  \
# Year
# 1980                                     False
# 1981                                     False
#
#       political_leadership_change_Yair Lapid  \
# Year
# 1980                                   False
# 1981                                   False
#
#       political_leadership_change_Yitzhak Rabin  \
# Year
# 1980                                      False
# 1981                                      False
#
#       political_leadership_change_Yitzḥak Shamir  Wars_fought_in_year_Yes
# Year
# 1980                                       False                    False
# 1981                                       False                    False

# %%
def boxplot(obj):
  i = obj.columns
  for i in obj:
    sns.boxplot(df[i])
    plt.tight_layout()
    plt.show()

# %%
boxplot(df)
# This visualization shows that only "Natural Disasters"
# have some outliers, most of the variables dont have outliers,
# the remaining are dummy variables.

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports', 'FDI', 'Population',
#        'Investment_in_Defence_year_wise', 'GDP',
#        'political_leadership_change_Benjamin Netanyahu',
#        'political_leadership_change_Ehud Barak',
#        'political_leadership_change_Ehud Olmert',
#        'political_leadership_change_Menachem Begin',
#        'political_leadership_change_Naftali Bennett',
#        'political_leadership_change_Shimon Peres',
#        'political_leadership_change_Yair Lapid',
#        'political_leadership_change_Yitzhak Rabin',
#        'political_leadership_change_Yitzḥak Shamir',
#        'Wars_fought_in_year_Yes'],
#       dtype='object')

# %%
from scipy.stats import kurtosis, skew
import numpy as np
# This i did to know the distribution pattern of
# the numerical variables, basically to know if
# any variable is Normally distributed.

# %%
df_numerical = df[['Natural_disasters', 'Exports', 'Imports', 'FDI', 'Population','Investment_in_Defence_year_wise', 'GDP']]

# %%
for i in df_numerical.columns:
  mean=df_numerical[i].mean()
  median=df_numerical[i].median()
  stddev=df_numerical[i].std()
  q1=df_numerical[i].quantile(0.25)
  q3=df_numerical[i].quantile(0.75)
  ku=kurtosis(df[i])
  sk=skew(df[i])
  IQR=q3-q1
  print(i, f'  Central Tendency : mean = {mean:.1f}, median = {median:.1f}')
  print( f'           Dispersion : stddev = {stddev:.1f} & IQR = {IQR : .1f}')
  print( f'          Shape Stats : skew = {sk:.1f} & kurtosis = {ku : .1f}')
  if ku > 3:
    print('             Kurtosis : Heavy tails (leptokurtic — more outliers)')
  if ku < 3:
    print('             Kurtosis : Light tails (platykurtic — fewer outliers)')
  if sk < 0:
    print('                 Skew : Left-skewed (long left tail)')
  if sk > 0:
    print('                 Skew : Right-skewed (long right tail)')
  if (ku == 0) & (sk == 0):
    print('  Normal Distribution : Yes')
  if (ku != 0) & (sk != 0):
    print('  Normal Distribution : No')
  print()
# Out:
# Natural_disasters   Central Tendency : mean = 71613.4, median = 0.0
#            Dispersion : stddev = 227277.0 & IQR =  0.0
#           Shape Stats : skew = 3.6 & kurtosis =  13.2
#              Kurtosis : Heavy tails (leptokurtic — more outliers)
#                  Skew : Right-skewed (long right tail)
#   Normal Distribution : No
#
# Exports   Central Tendency : mean = 58542964551.4, median = 42956388529.0
#            Dispersion : stddev = 45767672296.7 & IQR =  76324812486.5
#           Shape Stats : skew = 0.7 & kurtosis = -0.6
#              Kurtosis : Light tails (platykurtic — fewer outliers)
#                  Skew : Right-skewed (long right tail)
#   Normal Distribution : No
#
# Imports   Central Tendency : mean = 58434258527.4, median = 44932193847.3
#            Dispersion : stddev = 40664741995.7 & IQR =  70372128769.6
#           Shape Stats : skew = 0.6 & kurtosis = -0.7
#              Kurtosis : Light tails (platykurtic — fewer outliers)
#                  Skew : Right-skewed (long right tail)
#   Normal Distribution : No
#
# FDI   Central Tendency : mean = 6480248888.9, median = 3322000000.0
#            Dispersion : stddev = 7122325122.5 & IQR =  10990600000.0
#           Shape Stats : skew = 0.9 & kurtosis = -0.6
#              Kurtosis : Light tails (platykurtic — fewer outliers)
#                  Skew : Right-skewed (long right tail)
#   Normal Distribution : No
#
# Population   Central Tendency : mean = 6587215.6, median = 6570000.0
#            Dispersion : stddev = 1858230.6 & IQR =  3110500.0
#           Shape Stats : skew = 0.2 & kurtosis = -1.2
#              Kurtosis : Light tails (platykurtic — fewer outliers)
#                  Skew : Right-skewed (long right tail)
#   Normal Distribution : No
#
# Investment_in_Defence_year_wise   Central Tendency : mean = 16921207577.8, median = 14896905000.0
#            Dispersion : stddev = 5549088770.9 & IQR =  4115783000.0
#           Shape Stats : skew = 3.2 & kurtosis =  13.3
#              Kurtosis : Heavy tails (leptokurtic — more outliers)
#                  Skew : Right-skewed (long right tail)
#   Normal Distribution : No
#
# GDP   Central Tendency : mean = 189798129809.1, median = 135002039612.9
#            Dispersion : stddev = 151341051810.5 & IQR =  227479315666.2
#           Shape Stats : skew = 0.9 & kurtosis = -0.3
#              Kurtosis : Light tails (platykurtic — fewer outliers)
#                  Skew : Right-skewed (long right tail)
#   Normal Distribution : No

# %%
import seaborn as sns

# %%
for i in df_numerical.columns:
  sns.displot(df_numerical[i], kde=True)
  plt.tight_layout()
  plt.show()

# %%
# i will use Robust scaler for all the numercial variables,
# as no numerical variable is near to normal distribution.

# %%
from sklearn.preprocessing import RobustScaler, StandardScaler

# %%
df_numerical.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports', 'FDI', 'Population',
#        'Investment_in_Defence_year_wise', 'GDP'],
#       dtype='object')

# %%
rs = RobustScaler()

# %%
df[['Natural_disasters', 'Exports', 'Imports', 'FDI','Investment_in_Defence_year_wise', 'GDP']] = rs.fit_transform(df[['Natural_disasters', 'Exports', 'Imports', 'FDI','Investment_in_Defence_year_wise', 'GDP']])

# %%
df.head(4)
# Out:
#       Natural_disasters   Exports   Imports       FDI  Population  \
# Year
# 1980                0.0 -0.446530 -0.476005 -0.297618     3878000
# 1981                0.0 -0.443613 -0.464719 -0.291849     3956000
# 1982                0.0 -0.450952 -0.471862 -0.300320     4031000
# 1983                0.0 -0.448104 -0.467767 -0.295116     4105000
#
#       Investment_in_Defence_year_wise       GDP  \
# Year
# 1980                        -0.294368 -0.481832
# 1981                         0.282530 -0.475296
# 1982                        -0.005548 -0.464863
# 1983                        -0.402258 -0.449827
#
#       political_leadership_change_Benjamin Netanyahu  \
# Year
# 1980                                           False
# 1981                                           False
# 1982                                           False
# 1983                                           False
#
#       political_leadership_change_Ehud Barak  \
# Year
# 1980                                   False
# 1981                                   False
# 1982                                   False
# 1983                                   False
#
#       political_leadership_change_Ehud Olmert  \
# Year
# 1980                                    False
# 1981                                    False
# 1982                                    False
# 1983                                    False
#
#       political_leadership_change_Menachem Begin  \
# Year
# 1980                                        True
# 1981                                        True
# 1982                                        True
# 1983                                       False
#
#       political_leadership_change_Naftali Bennett  \
# Year
# 1980                                        False
# 1981                                        False
# 1982                                        False
# 1983                                        False
#
#       political_leadership_change_Shimon Peres  \
# Year
# 1980                                     False
# 1981                                     False
# 1982                                     False
# 1983                                     False
#
#       political_leadership_change_Yair Lapid  \
# Year
# 1980                                   False
# 1981                                   False
# 1982                                   False
# 1983                                   False
#
#       political_leadership_change_Yitzhak Rabin  \
# Year
# 1980                                      False
# 1981                                      False
# 1982                                      False
# 1983                                      False
#
#       political_leadership_change_Yitzḥak Shamir  Wars_fought_in_year_Yes
# Year
# 1980                                       False                    False
# 1981                                       False                    False
# 1982                                       False                     True
# 1983                                        True                    False

# %%
sc = StandardScaler()

# %%
df['Population']=sc.fit_transform(df[['Population']])

# %%
x = df.drop(['GDP'],axis=1)

# %%
y=df[['GDP']]

# %% [markdown]
# # EDA - 2 : MODEL SELECTION

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42 , test_size=0.3)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((31, 16), (14, 16), (31, 1), (14, 1))

# %% [markdown]
# # ELASTIC NET

# %% [markdown]
# ## Model building

# %% [markdown]
# ### Training dataset

# %%
from sklearn.linear_model import ElasticNet, Lasso, Ridge

# %%
en = ElasticNet()

# %%
model_en_train = en.fit(x_train,y_train)

# %%
model_en_train
# Out:
# ElasticNet()

# %%
y_pred_en_train = model_en_train.predict(x_train)

# %%
y_pred_en_train
# Out:
# array([0.18458175, 0.12435781, 0.2372597 , 0.19597396, 0.08887105,
#        0.10180962, 0.2218363 , 0.15602653, 0.15446493, 0.10900766,
#        0.56407482, 0.15260247, 0.10771021, 0.16965172, 0.16902493,
#        0.14474164, 0.98267463, 0.11523933, 0.1268976 , 0.18939469,
#        0.11146563, 0.92559907, 0.09928993, 0.114925  , 0.09923091,
#        0.58430552, 0.11209089, 0.13647873, 0.11316541, 0.15775864,
#        0.2257839 ])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ### Evaluation

# %%
# Calculate evaluation metrics
mse_en_train = mean_squared_error(y_train, y_pred_en_train)
rmse_en_train = mean_squared_error(y_train, y_pred_en_train)
mae_en_train = mean_absolute_error(y_train, y_pred_en_train)
r2_en_train = r2_score(y_train, y_pred_en_train)

print(f"Elastic Net Regression Training data Evaluation:")
print(f"Mean Squared Error (MSE): {mse_en_train:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_en_train:.4f}")
print(f"Mean Absolute Error (MAE): {mae_en_train:.4f}")
print(f"R-squared (R²) Score: {r2_en_train:.4f}")
# Out:
# Elastic Net Regression Training data Evaluation:
# Mean Squared Error (MSE): 0.2814
# Root Mean Squared Error (RMSE): 0.2814
# Mean Absolute Error (MAE): 0.4231
# R-squared (R²) Score: 0.2902

# %% [markdown]
# ### Testing Dataset

# %%
model_en_test=en.fit(x_test,y_test)

# %%
model_en_test
# Out:
# ElasticNet()

# %%
y_pred_net_test = model_en_test.predict(x_test)

# %%
y_pred_net_test
# Out:
# array([ 0.49661452,  0.29264059,  0.30193906,  0.62304593,  0.43057896,
#         0.53547059,  0.15761315, -0.2709412 ,  0.18927863,  0.13766253,
#         0.13856141,  0.28161749,  0.37603042,  0.17336555])

# %% [markdown]
# ### Evaluation

# %%
# Calculate evaluation metrics
mse_en_test = mean_squared_error(y_test, y_pred_net_test)
rmse_en_test = mean_squared_error(y_test, y_pred_net_test)
mae_en_test = mean_absolute_error(y_test, y_pred_net_test)
r2_en_test = r2_score(y_test, y_pred_net_test)

print(f"Elastic Net Regression Testing data Evaluation:")
print(f"Mean Squared Error (MSE): {mse_en_test:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_en_test:.4f}")
print(f"Mean Absolute Error (MAE): {mae_en_test:.4f}")
print(f"R-squared (R²) Score: {r2_en_test:.4f}")
# Out:
# Elastic Net Regression Testing data Evaluation:
# Mean Squared Error (MSE): 0.3057
# Root Mean Squared Error (RMSE): 0.3057
# Mean Absolute Error (MAE): 0.4652
# R-squared (R²) Score: 0.4022

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### Training dataset

# %%
from scipy.stats import uniform

# %%
param_distributions = {
    'alpha': uniform(0.001, 1),  # example distribution for alpha
    'l1_ratio': uniform(0, 1)    # example distribution for l1_ratio
}

# %%
grid_en_train = RandomizedSearchCV(
    ElasticNet(),
    param_distributions=param_distributions,
    n_iter=20,
    cv=5,
    n_jobs=-1,
    random_state=42
)

# %%
grid_en_train.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=ElasticNet(), n_iter=20, n_jobs=-1,
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7bb50896e3c0>,
#                                         'l1_ratio': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7bb4fafe3c50>},
#                    random_state=42)

# %%
grid_en_train.best_params_
# Out:
# {'alpha': np.float64(0.021584494295802448),
#  'l1_ratio': np.float64(0.9699098521619943)}

# %%
model_en_train_tuned = ElasticNet(alpha= 0.021584494295802448, l1_ratio=0.9699098521619943, random_state = 42)

# %%
model_en_train_tuned.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=0.021584494295802448, l1_ratio=0.9699098521619943,
#            random_state=42)

# %%
y_pred_net_tuned_train = model_en_train_tuned.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
model_en_train_tuned.intercept_
# Out:
# array([0.12502664])

# %%
feature_names = x.columns

# %%
coef = model_en_train_tuned.coef_

# %% [markdown]
# ### Testing dataset

# %%
param_grid = {'alpha': [1e-5, 1e-3, 1e-1, 1, 10, 100],'l1_ratio': [0, 0.25, 0.5, 0.75, 1]}

# %%
grid_en_test= RandomizedSearchCV(ElasticNet(), param_distributions=param_distributions, random_state =42)

# %%
grid_en_test.fit(x_test,y_test)
# Out:
# RandomizedSearchCV(estimator=ElasticNet(),
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7bb50896e3c0>,
#                                         'l1_ratio': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7bb4fafe3c50>},
#                    random_state=42)

# %%
grid_en_test.best_params_
# Out:
# {'alpha': np.float64(0.18282496720710062),
#  'l1_ratio': np.float64(0.18340450985343382)}

# %%
model_en_test_tuned = ElasticNet(alpha= 0.18282496720710062, l1_ratio=0.18340450985343382)

# %%
model_en_test_tuned.fit(x_test, y_test)
# Out:
# ElasticNet(alpha=0.18282496720710062, l1_ratio=0.18340450985343382)

# %%
y_pred_net_tuned_test = model_en_test_tuned.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
model_en_test_tuned.intercept_
model_en_train_tuned.intercept_
feature_names = x.columns
coef_en_test_tuned = model_en_test_tuned.coef_
coef_en_train_tuned = model_en_train_tuned.coef_

# %% [markdown]
# ## Evaluation - Tuned Dataset

# %%
# Calculate evaluation metrics
mse_en_train_tuned= mean_squared_error(y_train, y_pred_net_tuned_train)
rmse_en_train_tuned = mean_squared_error(y_train, y_pred_net_tuned_train)
mae_en_train_tuned = mean_absolute_error(y_train, y_pred_net_tuned_train)
r2_en_train_tuned = r2_score(y_train, y_pred_net_tuned_train)

print(f"Elastic Net Regression Train-Tuned Evaluation:")
print(f"Mean Squared Error (MSE): {mse_en_train_tuned:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_en_train_tuned:.4f}")
print(f"Mean Absolute Error (MAE): {mae_en_train_tuned:.4f}")
print(f"R-squared (R²) Score: {r2_en_train_tuned:.4f}")

print()
print()
# Calculate evaluation metrics
mse_en_test_tuned = mean_squared_error(y_test, y_pred_net_tuned_test)
rmse_en_test_tuned = mean_squared_error(y_test, y_pred_net_tuned_test)
mae_en_test_tuned = mean_absolute_error(y_test, y_pred_net_tuned_test)
r2_en_test_tuned = r2_score(y_test, y_pred_net_tuned_test)

print(f"Elastic Net Regression Test-Tuned Evaluation:")
print(f"Mean Squared Error (MSE): {mse_en_test_tuned:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_en_test_tuned:.4f}")
print(f"Mean Absolute Error (MAE): {mae_en_test_tuned:.4f}")
print(f"R-squared (R²) Score: {r2_en_test_tuned:.4f}")
# Out:
# Elastic Net Regression Train-Tuned Evaluation:
# Mean Squared Error (MSE): 0.0094
# Root Mean Squared Error (RMSE): 0.0094
# Mean Absolute Error (MAE): 0.0617
# R-squared (R²) Score: 0.9763
#
#
# Elastic Net Regression Test-Tuned Evaluation:
# Mean Squared Error (MSE): 0.0129
# Root Mean Squared Error (RMSE): 0.0129
# Mean Absolute Error (MAE): 0.0816
# R-squared (R²) Score: 0.9747

# %% [markdown]
# ## Significant features

# %%
# Identify significant features with non-zero coefficients
significant_features_en_train = [(name, c) for name, c in zip(feature_names, coef_en_train_tuned) if abs(c) > 1e-5]

print("Significant features and their coefficients - Training dataset:")
for name, coef_en_train_tuned in significant_features_en_train:
    print(f"{name}: {coef_en_train_tuned:.4f}")

print()
print()
    # Identify significant features with non-zero coefficients
significant_features_en_test = [(name, c) for name, c in zip(feature_names, coef_en_test_tuned) if abs(c) > 1e-5]

print("Significant features and their coefficients - Testing dataset:")
for name, coef_en_test_tuned in significant_features_en_test:
    print(f"{name}: {coef_en_test_tuned:.4f}")
# Out:
# Significant features and their coefficients - Training dataset:
# Exports: 0.1227
# FDI: 0.1481
# Population: 0.3554
# Investment_in_Defence_year_wise: 0.0887
#
#
# Significant features and their coefficients - Testing dataset:
# Exports: 0.0873
# Imports: 0.0693
# FDI: 0.0596
# Population: 0.2458
# Investment_in_Defence_year_wise: 0.2545

# %% [markdown]
# # RIDGE

# %% [markdown]
# ## Model building

# %%
rg = Ridge()

# %% [markdown]
# ### Training Dataset

# %%
rg_train_model = rg.fit(x_train, y_train)

# %%
y_pred_rg_train = rg_train_model.predict(x_train)

# %% [markdown]
# ### Evaluation

# %%
# Calculate evaluation metrics
mse_rg_train = mean_squared_error(y_train, y_pred_rg_train)
rmse_rg_train = mean_squared_error(y_train, y_pred_rg_train)
mae_rg_train = mean_absolute_error(y_train, y_pred_rg_train)
r2_rg_train = r2_score(y_train, y_pred_rg_train)

print(f"Elastic Net Regression Training data Evaluation:")
print(f"Mean Squared Error (MSE): {mse_rg_train:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_rg_train:.4f}")
print(f"Mean Absolute Error (MAE): {mae_rg_train:.4f}")
print(f"R-squared (R²) Score: {r2_rg_train:.4f}")
# Out:
# Elastic Net Regression Training data Evaluation:
# Mean Squared Error (MSE): 0.0022
# Root Mean Squared Error (RMSE): 0.0022
# Mean Absolute Error (MAE): 0.0348
# R-squared (R²) Score: 0.9945

# %% [markdown]
# ### Testing Dataset

# %%
rg_test_model = rg.fit(x_test, y_test)

# %%
y_pred_rg_test = rg_test_model.predict(x_test)

# %% [markdown]
# ### Evaluation

# %%
# Calculate evaluation metrics
mse_rg_test = mean_squared_error(y_test, y_pred_rg_test)
rmse_rg_test = mean_squared_error(y_test, y_pred_rg_test)
mae_rg_test = mean_absolute_error(y_test, y_pred_rg_test)
r2_rg_test = r2_score(y_test, y_pred_rg_test)

print(f"Elastic Net Regression Training data Evaluation:")
print(f"Mean Squared Error (MSE): {mse_rg_train:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_rg_train:.4f}")
print(f"Mean Absolute Error (MAE): {mae_rg_train:.4f}")
print(f"R-squared (R²) Score: {r2_rg_train:.4f}")
# Out:
# Elastic Net Regression Training data Evaluation:
# Mean Squared Error (MSE): 0.0022
# Root Mean Squared Error (RMSE): 0.0022
# Mean Absolute Error (MAE): 0.0348
# R-squared (R²) Score: 0.9945

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### Training Dataset

# %%
param_distributions = {
    'alpha': uniform(0.001, 10)  # alpha values between 0.001 and 10
}

# %%
gridrg_train_tuned= RandomizedSearchCV(rg , param_distributions=param_distributions, random_state=42)

# %%
gridrg_train_tuned.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(estimator=Ridge(),
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7bb4fabce3c0>},
#                    random_state=42)

# %%
gridrg_train_tuned.best_params_
# Out:
# {'alpha': np.float64(0.5818361216819946)}

# %%
rg_train = Ridge(alpha = 0.5818361216819946)

# %%
model_rg_train_tuned= rg_train.fit(x_train, y_train)

# %%
model_rg_train_tuned
# Out:
# Ridge(alpha=0.5818361216819946)

# %%
y_pred_rg_train_tuned = model_rg_train_tuned.predict(x_train)

# %% [markdown]
# ### Testing Dataset

# %%
gridrg_test_tuned= RandomizedSearchCV(rg , param_distributions=param_distributions, random_state=42)

# %%
gridrg_test_tuned.fit(x_test,y_test)
# Out:
# RandomizedSearchCV(estimator=Ridge(),
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7bb4fabce3c0>},
#                    random_state=42)

# %%
gridrg_test_tuned.best_params_
# Out:
# {'alpha': np.float64(5.987584841970366)}

# %%
rg_test_tuned = Ridge(alpha =(5.987584841970366))

# %%
model_rg_test_tuned= rg_test_tuned.fit(x_test,y_test)

# %%
model_rg_test_tuned
# Out:
# Ridge(alpha=5.987584841970366)

# %%
y_pred_rg_test_tuned = model_rg_test_tuned.predict(x_test)

# %%
model_rg_train_tuned.intercept_
feature_names = x.columns
coef_rg_train_tuned = model_rg_train_tuned.coef_

# %%
model_rg_test_tuned.intercept_
feature_names = x.columns
coef_rg_test_tuned = model_rg_test_tuned.coef_

# %% [markdown]
# ## Evaluation - Tuned Dataset

# %%
# Calculate evaluation metrics
mse_rg_train_tuned = mean_squared_error(y_train, y_pred_rg_train_tuned)
rmse_rg_train_tuned = mean_squared_error(y_train, y_pred_rg_train_tuned)
mae_rg_train_tuned = mean_absolute_error(y_train, y_pred_rg_train_tuned)
r2_rg_train_tuned = r2_score(y_train, y_pred_rg_train_tuned)

print(f"Ridge Regression Tuned - Training dataset Evaluation:")
print(f"Mean Squared Error (MSE): {mse_rg_train_tuned :.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_rg_train_tuned :.4f}")
print(f"Mean Absolute Error (MAE): {mae_rg_train_tuned :.4f}")
print(f"R-squared (R²) Score: {r2_rg_train_tuned:.4f}")

print()
print()
# Calculate evaluation metrics
mse_rg_test_tuned = mean_squared_error(y_test, y_pred_rg_test_tuned)
rmse_rg_test_tuned = mean_squared_error(y_test, y_pred_rg_test_tuned)
mae_rg_test_tuned = mean_absolute_error(y_test, y_pred_rg_test_tuned)
r2_rg_test_tuned = r2_score(y_test, y_pred_rg_test_tuned)

print(f"Ridge Regression Tuned - Testing dataset Evaluation:")
print(f"Mean Squared Error (MSE): {mse_rg_test_tuned :.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_rg_test_tuned :.4f}")
print(f"Mean Absolute Error (MAE): {mae_rg_test_tuned :.4f}")
print(f"R-squared (R²) Score: {r2_rg_test_tuned :.4f}")
# Out:
# Ridge Regression Training dataset Evaluation:
# Mean Squared Error (MSE): 0.0017
# Root Mean Squared Error (RMSE): 0.0017
# Mean Absolute Error (MAE): 0.0328
# R-squared (R²) Score: 0.9958
#
#
# Ridge Regression Testing dataset Evaluation:
# Mean Squared Error (MSE): 0.0133
# Root Mean Squared Error (RMSE): 0.0133
# Mean Absolute Error (MAE): 0.0828
# R-squared (R²) Score: 0.9740

# %% [markdown]
# ## Significant features

# %%
# Identify significant features with non-zero coefficients
significant_features_rg_train_tuned = [(name, c) for name, c in zip(feature_names, coef_rg_train_tuned) if abs(c) > 1e-5]

print("Significant features and their coefficients - Training Dataset:")
for name, coef_rg_train_tuned in significant_features_rg_train_tuned:
    print(f"{name}: {coef_rg_train_tuned:.4f}")
# Out:
# Significant features and their coefficients - Training Dataset:
# Exports: 0.2131
# Imports: 0.1961
# FDI: 0.1602
# Population: 0.2045
# Investment_in_Defence_year_wise: 0.0748
# political_leadership_change_Benjamin Netanyahu: 0.0432
# political_leadership_change_Ehud Barak: -0.0412
# political_leadership_change_Ehud Olmert: -0.1118
# political_leadership_change_Menachem Begin: -0.0019
# political_leadership_change_Shimon Peres: 0.0164
# political_leadership_change_Yair Lapid: 0.1649
# political_leadership_change_Yitzhak Rabin: 0.0164
# political_leadership_change_Yitzḥak Shamir: 0.0243
# Wars_fought_in_year_Yes: -0.0168

# %%
# Identify significant features with non-zero coefficients
significant_features_rg_test_tuned = [(name, c) for name, c in zip(feature_names, coef_rg_test_tuned) if abs(c) > 1e-5]

print("Significant features and their coefficients - Testing Dataset:")
for name, coef_rg_test_tuned in significant_features_rg_test_tuned:
    print(f"{name}: {coef_rg_test_tuned:.4f}")
# Out:
# Significant features and their coefficients - Testing Dataset:
# Exports: 0.1228
# Imports: 0.1151
# FDI: 0.1075
# Population: 0.1837
# Investment_in_Defence_year_wise: 0.2036
# political_leadership_change_Benjamin Netanyahu: 0.0417
# political_leadership_change_Ehud Barak: 0.0038
# political_leadership_change_Ehud Olmert: -0.0259
# political_leadership_change_Naftali Bennett: 0.0508
# political_leadership_change_Shimon Peres: -0.0177
# political_leadership_change_Yitzhak Rabin: -0.0004
# political_leadership_change_Yitzḥak Shamir: -0.0244
# Wars_fought_in_year_Yes: -0.0002

# %% [markdown]
# # LASSO

# %% [markdown]
# ## Model building

# %% [markdown]
# ### Training Dataset

# %%
ls = Lasso()

# %%
lasso_model_train = ls.fit(x_train,y_train)

# %%
y_pred_ls_train = lasso_model_train.predict(x_train)

# %% [markdown]
# ### Evaluation

# %%
# Calculate evaluation metrics
mse_ls_train = mean_squared_error(y_train, y_pred_ls_train)
rmse_ls_train = mean_squared_error(y_train, y_pred_ls_train)
mae_ls_train = mean_absolute_error(y_train, y_pred_ls_train)
r2_ls_train = r2_score(y_train, y_pred_ls_train)

print(f"Elastic Net Regression Training data Evaluation:")
print(f"Mean Squared Error (MSE): {mse_rg_train:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_rg_train:.4f}")
print(f"Mean Absolute Error (MAE): {mae_rg_train:.4f}")
print(f"R-squared (R²) Score: {r2_rg_train:.4f}")
# Out:
# Elastic Net Regression Training data Evaluation:
# Mean Squared Error (MSE): 0.0022
# Root Mean Squared Error (RMSE): 0.0022
# Mean Absolute Error (MAE): 0.0348
# R-squared (R²) Score: 0.9945

# %% [markdown]
# ### Testing Dataset

# %%
ls = Lasso()

# %%
lasso_model_test = ls.fit(x_test,y_test)

# %%
y_pred_ls_test = lasso_model_test.predict(x_test)

# %% [markdown]
# ### Evaluation

# %%
# Calculate evaluation metrics
mse_ls_test = mean_squared_error(y_test, y_pred_ls_test)
rmse_ls_test = mean_squared_error(y_test, y_pred_ls_test)
mae_ls_test = mean_absolute_error(y_test, y_pred_ls_test)
r2_ls_test = r2_score(y_test, y_pred_ls_test)

print(f"Elastic Net Regression Training data Evaluation:")
print(f"Mean Squared Error (MSE): {mse_rg_test:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_rg_test:.4f}")
print(f"Mean Absolute Error (MAE): {mae_rg_test:.4f}")
print(f"R-squared (R²) Score: {r2_rg_test:.4f}")
# Out:
# Elastic Net Regression Training data Evaluation:
# Mean Squared Error (MSE): 0.0022
# Root Mean Squared Error (RMSE): 0.0022
# Mean Absolute Error (MAE): 0.0362
# R-squared (R²) Score: 0.9956

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### Training Dataset

# %%
# Define parameter distribution for Lasso
param_distributions = {
    'alpha': uniform(0.0001, 10)  # alpha sampled uniformly between 0.0001 and 10
}

# %%
grid_ls =RandomizedSearchCV(ls, param_distributions=param_distributions, random_state =42)

# %%
model_ls_train=grid_ls.fit(x_train, y_train)

# %%
model_ls_train.best_params_
# Out:
# {'alpha': np.float64(0.5809361216819946)}

# %%
model_ls_train_tuned = Lasso(alpha =0.5809361216819946)

# %%
model_lasso_train_tuned = model_ls_train_tuned.fit(x_train, y_train)

# %%
model_lasso_train_tuned
# Out:
# Lasso(alpha=0.5809361216819946)

# %%
y_pred_lasso_train = model_lasso_train_tuned.predict(x_train)

# %% [markdown]
# ### Testing Dataset

# %%
model_ls_test=grid_ls.fit(x_test, y_test)

# %%
model_ls_test.best_params_
# Out:
# {'alpha': np.float64(0.5809361216819946)}

# %%
model_ls_test_tuned = Lasso(alpha =0.5809361216819946)

# %%
model_lasso_test_tuned = model_ls_test_tuned.fit(x_test, y_test)

# %%
model_lasso_test_tuned
# Out:
# Lasso(alpha=0.5809361216819946)

# %%
y_pred_lasso_test = model_lasso_test_tuned.predict(x_test)

# %% [markdown]
# ## Evaluation - Tuned Dataset

# %%
# Calculate evaluation metrics
mse_lasso_train_tuned = mean_squared_error(y_train, y_pred_lasso_train)
rmse_lasso_train_tuned = mean_squared_error(y_train, y_pred_lasso_train)
mae_lasso_train_tuned = mean_absolute_error(y_train, y_pred_lasso_train)
r2_lasso_train_tuned = r2_score(y_train, y_pred_lasso_train)

print(f"Lasso Regression Evaluation - Training Dataset:")
print(f"Mean Squared Error (MSE): {mse_lasso_train_tuned:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_lasso_train_tuned:.4f}")
print(f"Mean Absolute Error (MAE): {mae_lasso_train_tuned:.4f}")
print(f"R-squared (R²) Score: {r2_lasso_train_tuned:.4f}")

print()
print()

# Calculate evaluation metrics
mse_lasso_test_tuned = mean_squared_error(y_test, y_pred_lasso_test)
rmse_lasso_test_tuned = mean_squared_error(y_test, y_pred_lasso_test)
mae_lasso_test_tuned = mean_absolute_error(y_test, y_pred_lasso_test)
r2_lasso_test_tuned = r2_score(y_test, y_pred_lasso_test)

print(f"Lasso Regression Evaluation - Testing Dataset:")
print(f"Mean Squared Error (MSE): {mse_lasso_test_tuned:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_lasso_test_tuned:.4f}")
print(f"Mean Absolute Error (MAE): {mae_lasso_test_tuned:.4f}")
print(f"R-squared (R²) Score: {r2_lasso_test_tuned:.4f}")
# Out:
# Lasso Regression Evaluation - Training Dataset:
# Mean Squared Error (MSE): 0.3089
# Root Mean Squared Error (RMSE): 0.3089
# Mean Absolute Error (MAE): 0.4422
# R-squared (R²) Score: 0.2210
#
#
# Lasso Regression Evaluation - Testing Dataset:
# Mean Squared Error (MSE): 0.3563
# Root Mean Squared Error (RMSE): 0.3563
# Mean Absolute Error (MAE): 0.5029
# R-squared (R²) Score: 0.3032

# %%
model_lasso_test_tuned.intercept_
feature_names = x.columns
coef_lasso_test_tuned = model_lasso_test_tuned.coef_

model_lasso_train_tuned.intercept_
feature_names = x.columns
coef_lasso_train_tuned = model_lasso_train_tuned.coef_

# %% [markdown]
# ## Significant features

# %%
# Identify significant features with non-zero coefficients
significant_features_lasso_train_tuned = [(name, c) for name, c in zip(feature_names, coef_lasso_train_tuned) if abs(c) > 1e-5]

print("Significant features and their coefficients - Training Dataset:")
for name, coef_lasso_train_tuned in significant_features_lasso_train_tuned:
    print(f"{name}: {coef_lasso_train_tuned:.4f}")

print()
print()

# Identify significant features with non-zero coefficients
significant_features_lasso_test_tuned = [(name, c) for name, c in zip(feature_names, coef_lasso_test_tuned) if abs(c) > 1e-5]

print("Significant features and their coefficients - Testing Dataset:")
for name, coef_lasso_test_tuned in significant_features_lasso_test_tuned:
    print(f"{name}: {coef_lasso_test_tuned:.4f}")
# Out:
# Significant features and their coefficients - Training Dataset:
# Investment_in_Defence_year_wise: 0.0373
#
#
# Significant features and their coefficients - Testing Dataset:
# Population: 0.1027
# Investment_in_Defence_year_wise: 0.0002

# %% [markdown]
# # KNN

# %% [markdown]
# ## Model building

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor()

# %% [markdown]
# ### Training Dataset

# %%
model_knn_train = knn.fit(x_train, y_train)
y_pred_knn_train = model_knn_train.predict(x_train)

# %% [markdown]
# ### Evaluation

# %%
# Calculate evaluation metrics
mse_knn_train = mean_squared_error(y_train, y_pred_knn_train)
rmse_knn_train = mean_squared_error(y_train, y_pred_knn_train)
mae_knn_train = mean_absolute_error(y_train, y_pred_knn_train)
r2_knn_train = r2_score(y_train, y_pred_knn_train)

print(f"KNN Training data Evaluation:")
print(f"Mean Squared Error (MSE): {mse_knn_train:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_knn_train:.4f}")
print(f"Mean Absolute Error (MAE): {mae_knn_train:.4f}")
print(f"R-squared (R²) Score: {r2_knn_train:.4f}")
# Out:
# KNN Training data Evaluation:
# Mean Squared Error (MSE): 0.0497
# Root Mean Squared Error (RMSE): 0.0497
# Mean Absolute Error (MAE): 0.1203
# R-squared (R²) Score: 0.8747

# %% [markdown]
# ### Testing Dataset

# %%
model_knn_test = knn.fit(x_test, y_test)
y_pred_knn_test = model_knn_test.predict(x_test)

# %% [markdown]
# ### Evaluation

# %%
# Calculate evaluation metrics
mse_knn_test = mean_squared_error(y_test, y_pred_knn_test)
rmse_knn_test = mean_squared_error(y_test, y_pred_knn_test)
mae_knn_test = mean_absolute_error(y_test, y_pred_knn_test)
r2_knn_test = r2_score(y_test, y_pred_knn_test)

print(f"KNN Testing data Evaluation:")
print(f"Mean Squared Error (MSE): {mse_knn_test:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_knn_test:.4f}")
print(f"Mean Absolute Error (MAE): {mae_knn_test:.4f}")
print(f"R-squared (R²) Score: {r2_knn_test:.4f}")
# Out:
# KNN Testing data Evaluation:
# Mean Squared Error (MSE): 0.0481
# Root Mean Squared Error (RMSE): 0.0481
# Mean Absolute Error (MAE): 0.1658
# R-squared (R²) Score: 0.9059

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# ### Training Dataset

# %%
from scipy.stats import randint

# %%
# Define parameter distributions
param_distributions = {
    'n_neighbors': randint(1, 30),            # Number of neighbors between 1 and 30
    'weights': ['uniform', 'distance'],       # Weighting options
    'p': [1, 2],                             # Distance metrics: Manhattan (1) or Euclidean (2)
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']  # Search algorithms
}

# %%
grid_knn_train = RandomizedSearchCV(knn, param_distributions=param_distributions, random_state =42)

# %%
grid_knn_train.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 24, n_samples = 7
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 25, n_samples = 6
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 25, n_samples = 6
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 25, n_samples = 6
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 25, n_samples = 6
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [-0.03147109  0.74608865         nan  0.63658663  0.73129396  0.43612898
#   0.84232542  0.52680375  0.52120382  0.30143967]
#   warnings.warn(
# RandomizedSearchCV(estimator=KNeighborsRegressor(),
#                    param_distributions={'algorithm': ['auto', 'ball_tree',
#                                                       'kd_tree', 'brute'],
#                                         'n_neighbors': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7bb4fae74740>,
#                                         'p': [1, 2],
#                                         'weights': ['uniform', 'distance']},
#                    random_state=42)

# %%
grid_knn_train.best_params_
# Out:
# {'algorithm': 'brute', 'n_neighbors': 6, 'p': 2, 'weights': 'distance'}

# %%
knn1 = KNeighborsRegressor(algorithm='brute', n_neighbors=6, p=2, weights='distance')

# %%
knn1.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='brute', n_neighbors=6, weights='distance')

# %%
y_pred_knn_train = knn1.predict(x_train)

# %% [markdown]
# ### Testing Dataset

# %%
grid_knn_test = RandomizedSearchCV(knn, param_distributions=param_distributions, random_state =42)

# %%
grid_knn_test.fit(x_test,y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 20, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 20, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 20, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 20, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 20, n_samples_fit = 12, n_samples = 2
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 26, n_samples_fit = 12, n_samples = 2
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 12, n_samples = 2
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 21, n_samples_fit = 12, n_samples = 2
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 22, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 22, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 22, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 22, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 246, in predict
#     neigh_dist, neigh_ind = self.kneighbors(X)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 22, n_samples_fit = 12, n_samples = 2
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 11, n_samples = 3
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 12, n_samples = 2
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [         nan -11.2577308           nan -21.02396675 -11.24991052
#           nan  -2.13582603          nan          nan          nan]
#   warnings.warn(
# RandomizedSearchCV(estimator=KNeighborsRegressor(),
#                    param_distributions={'algorithm': ['auto', 'ball_tree',
#                                                       'kd_tree', 'brute'],
#                                         'n_neighbors': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7bb4fae74740>,
#                                         'p': [1, 2],
#                                         'weights': ['uniform', 'distance']},
#                    random_state=42)

# %%
grid_knn_test.best_params_
# Out:
# {'algorithm': 'brute', 'n_neighbors': 6, 'p': 2, 'weights': 'distance'}

# %%
knn2 = KNeighborsRegressor(algorithm='brute', n_neighbors=6, p=2, weights='distance')

# %%
knn2.fit(x_test,y_test)
# Out:
# KNeighborsRegressor(algorithm='brute', n_neighbors=6, weights='distance')

# %%
y_pred_knn_test = knn2.predict(x_test)

# %% [markdown]
# ## Evaluation -Tuned Dataset

# %%
# Calculate MSE
mse_knn_train = mean_squared_error(y_pred_knn_train, y_train)

# Calculate RMSE
rmse_knn_train = mean_squared_error(y_train, y_pred_knn_train)  # or np.sqrt(mse)

# Calculate MAE
mae_knn_train = mean_absolute_error(y_pred_knn_train, y_train)

# Calculate R-squared
r2_knn_train = r2_score(y_pred_knn_train, y_train)

print(f"KNN Tuned Evaluation - Training Dataset")
print(f"Mean Squared Error (MSE): {mse_knn_train:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_knn_train:.4f}")
print(f"Mean Absolute Error (MAE): {mae_knn_train:.4f}")
print(f"R-squared (R²): {r2_knn_train:.4f}")

print()
print()

# Calculate MSE
mse_knn_test = mean_squared_error(y_pred_knn_test, y_test)

# Calculate RMSE
rmse_knn_test = mean_squared_error(y_test, y_pred_knn_test)  # or np.sqrt(mse)

# Calculate MAE
mae_knn_test = mean_absolute_error(y_pred_knn_test, y_test)

# Calculate R-squared
r2_knn_test = r2_score(y_pred_knn_test, y_test)

print(f"KNN Tuned Evaluation - Testing Dataset")
print(f"Mean Squared Error (MSE): {mse_knn_test:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_knn_test:.4f}")
print(f"Mean Absolute Error (MAE): {mae_knn_test:.4f}")
print(f"R-squared (R²): {r2_knn_test:.4f}")
# Out:
# KNN Tuned Evaluation - Training Dataset
# Mean Squared Error (MSE): 0.0000
# Root Mean Squared Error (RMSE): 0.0000
# Mean Absolute Error (MAE): 0.0000
# R-squared (R²): 1.0000
#
#
# KNN Tuned Evaluation - Testing Dataset
# Mean Squared Error (MSE): 0.0000
# Root Mean Squared Error (RMSE): 0.0000
# Mean Absolute Error (MAE): 0.0000
# R-squared (R²): 1.0000

# %% [markdown]
# ## Significant features

# %%
from sklearn.inspection import permutation_importance

# %%
results_train = permutation_importance(knn1, x_train, y_train, scoring='r2')
importance_train = results_train.importances_mean

for i, v in enumerate(importance_train):
    print(f'Feature: {x.columns[i]}, Importance: {v:.4f}')
# Out:
# Feature: Natural_disasters, Importance: 0.2997
# Feature: Exports, Importance: 0.0453
# Feature: Imports, Importance: 0.0440
# Feature: FDI, Importance: 0.0534
# Feature: Population, Importance: 0.1342
# Feature: Investment_in_Defence_year_wise, Importance: 0.1862
# Feature: political_leadership_change_Benjamin Netanyahu, Importance: 0.0239
# Feature: political_leadership_change_Ehud Barak, Importance: 0.0001
# Feature: political_leadership_change_Ehud Olmert, Importance: 0.0112
# Feature: political_leadership_change_Menachem Begin, Importance: 0.0069
# Feature: political_leadership_change_Naftali Bennett, Importance: 0.0000
# Feature: political_leadership_change_Shimon Peres, Importance: 0.0062
# Feature: political_leadership_change_Yair Lapid, Importance: 0.0237
# Feature: political_leadership_change_Yitzhak Rabin, Importance: 0.0009
# Feature: political_leadership_change_Yitzḥak Shamir, Importance: 0.0031
# Feature: Wars_fought_in_year_Yes, Importance: 0.0208

# %%
results_test = permutation_importance(knn2, x_test, y_test, scoring='r2')
importance_test = results_test.importances_mean

for i, v in enumerate(importance_test):
    print(f'Feature: {x.columns[i]}, Importance: {v:.4f}')
# Out:
# Feature: Natural_disasters, Importance: 0.2745
# Feature: Exports, Importance: 0.0854
# Feature: Imports, Importance: 0.0819
# Feature: FDI, Importance: 0.0798
# Feature: Population, Importance: 0.2194
# Feature: Investment_in_Defence_year_wise, Importance: 0.3122
# Feature: political_leadership_change_Benjamin Netanyahu, Importance: 0.0473
# Feature: political_leadership_change_Ehud Barak, Importance: 0.0085
# Feature: political_leadership_change_Ehud Olmert, Importance: 0.0009
# Feature: political_leadership_change_Menachem Begin, Importance: 0.0000
# Feature: political_leadership_change_Naftali Bennett, Importance: 0.0313
# Feature: political_leadership_change_Shimon Peres, Importance: 0.0141
# Feature: political_leadership_change_Yair Lapid, Importance: 0.0000
# Feature: political_leadership_change_Yitzhak Rabin, Importance: 0.0009
# Feature: political_leadership_change_Yitzḥak Shamir, Importance: 0.0275
# Feature: Wars_fought_in_year_Yes, Importance: 0.0528
