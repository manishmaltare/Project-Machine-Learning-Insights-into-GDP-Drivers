# %% [markdown]
# # DATA LOADING

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/israel1.xlsx',sheet_name='Sheet1')

# %%
df.head()
# Out:
#    Year  Natural disasters       Exports       Imports  \
# 0  1980                NaN  8.875098e+09  1.143471e+10
# 1  1981                NaN  9.097719e+09  1.222895e+10
# 2  1982                NaN  8.537572e+09  1.172626e+10
# 3  1983                NaN  8.754929e+09  1.201441e+10
# 4  1984                NaN  9.523963e+09  1.201263e+10
#
#   political leadership change type of leadership        FDI  Population  \
# 0              Menachem Begin         Democratic   51000000     3878000
# 1              Menachem Begin         Democratic  114400000     3956000
# 2              Menachem Begin         Democratic   21300000     4031000
# 3              Yitzḥak Shamir         Democratic   78500000     4105000
# 4                Shimon Peres         Democratic   89500000     4159000
#
#   Wars fought in year  Investment in Defence year wise           GDP
# 0                  No                      13685349000  2.539526e+10
# ...

# %%
df.shape
# Out:
# (45, 11)

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             45 non-null     int64
#  1   Natural disasters                8 non-null      float64
#  2   Exports                          45 non-null     float64
#  3   Imports                          45 non-null     float64
#  4   political leadership change      45 non-null     object
#  5   type of leadership               45 non-null     object
#  6   FDI                              45 non-null     int64
#  7   Population                       45 non-null     int64
#  8   Wars fought in year              45 non-null     object
#  9   Investment in Defence year wise  45 non-null     int64
#  10  GDP                              45 non-null     float64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 4.0+ KB

# %%
df.isnull().sum()
# Out:
# Year                                0
# Natural disasters                  37
# Exports                             0
# Imports                             0
# political leadership change         0
# type of leadership                  0
# FDI                                 0
# Population                          0
# Wars fought in year                 0
# Investment in Defence year wise     0
# GDP                                 0
# dtype: int64

# %%
df[['Natural disasters']] = df[['Natural disasters']].fillna(0)

# %%
df.describe()
# Out:
#               Year  Natural disasters       Exports       Imports  \
# count    45.000000       4.500000e+01  4.500000e+01  4.500000e+01
# mean   2002.000000       7.161342e+04  5.854296e+10  5.843426e+10
# std      13.133926       2.272770e+05  4.576767e+10  4.066474e+10
# min    1980.000000       0.000000e+00  8.537572e+09  1.143471e+10
# 25%    1991.000000       0.000000e+00  1.733152e+10  2.253411e+10
# 50%    2002.000000       0.000000e+00  4.295639e+10  4.493219e+10
# 75%    2013.000000       0.000000e+00  9.365633e+10  9.290624e+10
# max    2024.000000       1.194341e+06  1.648298e+11  1.536655e+11
#
#                 FDI    Population  Investment in Defence year wise  \
# count  4.500000e+01  4.500000e+01                     4.500000e+01
# mean   6.480249e+09  6.587216e+06                     1.692121e+10
# std    7.122325e+09  1.858231e+06                     5.549089e+09
# min    2.130000e+07  3.878000e+06                     1.234735e+10
# ...

# %%
df.set_index('Year', inplace=True)

# %%
df.head(4)
# Out:
#       Natural disasters       Exports       Imports  \
# Year
# 1980                0.0  8.875098e+09  1.143471e+10
# 1981                0.0  9.097719e+09  1.222895e+10
# 1982                0.0  8.537572e+09  1.172626e+10
# 1983                0.0  8.754929e+09  1.201441e+10
#
#      political leadership change type of leadership        FDI  Population  \
# Year
# 1980              Menachem Begin         Democratic   51000000     3878000
# 1981              Menachem Begin         Democratic  114400000     3956000
# 1982              Menachem Begin         Democratic   21300000     4031000
# 1983              Yitzḥak Shamir         Democratic   78500000     4105000
#
#      Wars fought in year  Investment in Defence year wise           GDP
# Year
# 1980                  No                      13685349000  2.539526e+10
# 1981                  No                      16059739000  2.688201e+10
# 1982                 Yes                      14874069000  2.925529e+10
# ...

# %%
df.isnull().sum()
# Out:
# Natural disasters                  0
# Exports                            0
# Imports                            0
# political leadership change        0
# type of leadership                 0
# FDI                                0
# Population                         0
# Wars fought in year                0
# Investment in Defence year wise    0
# GDP                                0
# dtype: int64

# %%
df.nunique()
# Out:
# Natural disasters                   9
# Exports                            45
# Imports                            45
# political leadership change        10
# type of leadership                  1
# FDI                                45
# Population                         45
# Wars fought in year                 2
# Investment in Defence year wise    45
# GDP                                45
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Natural disasters                   9
# Exports                            45
# Imports                            45
# political leadership change        10
# type of leadership                  1
# FDI                                45
# Population                         45
# Wars fought in year                 2
# Investment in Defence year wise    45
# GDP                                45
# dtype: int64

# %%
df.columns
# Out:
# Index(['Natural disasters', 'Exports', 'Imports',
#        'political leadership change', 'type of leadership', 'FDI',
#        'Population', 'Wars fought in year', 'Investment in Defence year wise',
#        'GDP'],
#       dtype='object')

# %%
df.rename(columns={'Natural disasters': 'Natural_disasters',
       'political leadership change' :'political_leadership_change' , 'type of leadership': 'type_of_government',
       'Wars fought in year' : 'Wars_fought_in_year', 'Investment in Defence year wise':'Investment_in_Defence_year_wise'}, inplace=True)

# %%
df.head(3)
# Out:
#       Natural_disasters       Exports       Imports  \
# Year
# 1980                0.0  8.875098e+09  1.143471e+10
# 1981                0.0  9.097719e+09  1.222895e+10
# 1982                0.0  8.537572e+09  1.172626e+10
#
#      political_leadership_change type_of_government        FDI  Population  \
# Year
# 1980              Menachem Begin         Democratic   51000000     3878000
# 1981              Menachem Begin         Democratic  114400000     3956000
# 1982              Menachem Begin         Democratic   21300000     4031000
#
#      Wars_fought_in_year  Investment_in_Defence_year_wise           GDP
# Year
# 1980                  No                      13685349000  2.539526e+10
# 1981                  No                      16059739000  2.688201e+10
# 1982                 Yes                      14874069000  2.925529e+10

# %%
df.corr(numeric_only=True)
# Out:
#                                  Natural_disasters   Exports   Imports  \
# Natural_disasters                         1.000000  0.031495  0.021455
# Exports                                   0.031495  1.000000  0.997339
# Imports                                   0.021455  0.997339  1.000000
# FDI                                       0.077800  0.926402  0.920365
# Population                                0.081480  0.970475  0.973401
# Investment_in_Defence_year_wise           0.008805  0.769052  0.751460
# GDP                                       0.067788  0.989861  0.983473
#
#                                       FDI  Population  \
# Natural_disasters                0.077800    0.081480
# Exports                          0.926402    0.970475
# Imports                          0.920365    0.973401
# FDI                              1.000000    0.900873
# Population                       0.900873    1.000000
# Investment_in_Defence_year_wise  0.687000    0.704569
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# This visualization shows that the variables are
# highly multicollinear, SO we can't use the MLR
# method here.
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
i=df.columns
i
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
def regplot(obj,l):
  i=obj.columns
  for i in obj:
    sns.regplot(x=obj[i], y=l)
    plt.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports',
#        'political_leadership_change', 'type_of_government', 'FDI',
#        'Population', 'Wars_fought_in_year', 'Investment_in_Defence_year_wise',
#        'GDP'],
#       dtype='object')

# %%
df.drop(['type_of_government'], axis=1, inplace=True)

# %%
df = pd.get_dummies(df,drop_first=False)

# %%
df.nunique()
# Out:
# Natural_disasters                                  9
# Exports                                           45
# Imports                                           45
# FDI                                               45
# Population                                        45
# Investment_in_Defence_year_wise                   45
# GDP                                               45
# political_leadership_change_Ariel Sharon           2
# political_leadership_change_Benjamin Netanyahu     2
# political_leadership_change_Ehud Barak             2
# political_leadership_change_Ehud Olmert            2
# political_leadership_change_Menachem Begin         2
# political_leadership_change_Naftali Bennett        2
# political_leadership_change_Shimon Peres           2
# political_leadership_change_Yair Lapid             2
# political_leadership_change_Yitzhak Rabin          2
# political_leadership_change_Yitzḥak Shamir         2
# Wars_fought_in_year_No                             2
# ...

# %%
df.head(2)
# Out:
#       Natural_disasters       Exports       Imports        FDI  Population  \
# Year
# 1980                0.0  8.875098e+09  1.143471e+10   51000000     3878000
# 1981                0.0  9.097719e+09  1.222895e+10  114400000     3956000
#
#       Investment_in_Defence_year_wise           GDP  \
# Year
# 1980                      13685349000  2.539526e+10
# 1981                      16059739000  2.688201e+10
#
#       political_leadership_change_Ariel Sharon  \
# Year
# 1980                                     False
# 1981                                     False
#
#       political_leadership_change_Benjamin Netanyahu  \
# Year
# 1980                                           False
# 1981                                           False
#
#       political_leadership_change_Ehud Barak  \
# Year
# 1980                                   False
# 1981                                   False
#
#       political_leadership_change_Ehud Olmert  \
# Year
# ...

# %%
def boxplot(obj):
  i = obj.columns
  for i in obj:
    sns.boxplot(df[i])
    plt.tight_layout()
    plt.show()

# %%
boxplot(df)
# This visualization shows that only "Natural Disasters"
# have some outliers, most of the variables dont have outliers,
# the remaining are dummy variables.

# %%
df.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports', 'FDI', 'Population',
#        'Investment_in_Defence_year_wise', 'GDP',
#        'political_leadership_change_Ariel Sharon',
#        'political_leadership_change_Benjamin Netanyahu',
#        'political_leadership_change_Ehud Barak',
#        'political_leadership_change_Ehud Olmert',
#        'political_leadership_change_Menachem Begin',
#        'political_leadership_change_Naftali Bennett',
#        'political_leadership_change_Shimon Peres',
#        'political_leadership_change_Yair Lapid',
#        'political_leadership_change_Yitzhak Rabin',
#        'political_leadership_change_Yitzḥak Shamir', 'Wars_fought_in_year_No',
#        'Wars_fought_in_year_Yes'],
#       dtype='object')

# %%
x = df.drop(['GDP'],axis=1)

# %%
x.head(2)
# Out:
#       Natural_disasters       Exports       Imports        FDI  Population  \
# Year
# 1980                0.0  8.875098e+09  1.143471e+10   51000000     3878000
# 1981                0.0  9.097719e+09  1.222895e+10  114400000     3956000
#
#       Investment_in_Defence_year_wise  \
# Year
# 1980                      13685349000
# 1981                      16059739000
#
#       political_leadership_change_Ariel Sharon  \
# Year
# 1980                                     False
# 1981                                     False
#
#       political_leadership_change_Benjamin Netanyahu  \
# Year
# 1980                                           False
# 1981                                           False
#
#       political_leadership_change_Ehud Barak  \
# Year
# 1980                                   False
# 1981                                   False
#
#       political_leadership_change_Ehud Olmert  \
# Year
# 1980                                    False
# ...

# %%
y=df['GDP']

# %%
# Applying the ML algorithms
from sklearn.model_selection import GridSearchCV, train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42, train_size=0.8)

# %% [markdown]
# # DECISION TREE

# %% [markdown]
# ### Training Dataset

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree_train= DecisionTreeRegressor()

# %%
model_dtree_train = dtree_train.fit(x_train,y_train)

# %%
y_pred_train = model_dtree_train.predict(x_train)

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
r2_score_train=r2_score(y_pred_train, y_train)

print(f"R2-score : {r2_score_train}")
# Out:
# R2-score : 1.0

# %% [markdown]
# ### Testing Dataset

# %%
dtree_test= DecisionTreeRegressor()

# %%
model_dtree_test = dtree_test.fit(x_test,y_test)

# %%
y_pred_test = model_dtree_test.predict(x_test)

# %% [markdown]
# ### Evaluation

# %%
r2_score_test=r2_score(y_pred_test, y_test)

print(f"R2-score : {r2_score_test}")
# Out:
# R2-score : 1.0

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# ### Training Dataset

# %%
# I am doing Hyperparameter Tuning also.

# %%
param_grid = {'criterion': ['squared_error','friedman_mse','absolute_error','poisson'],'max_depth': [1,2, 3, 4, 5, None],'min_samples_split': [1,2, 5, 10],'min_samples_leaf': [1, 2, 4]}

# %%
# Training the Model : 80% data

# %%
dtree1= DecisionTreeRegressor(criterion='squared_error',max_depth=2,min_samples_leaf=1,min_samples_split=2,random_state = 42)
# applied the Best Hyperparameter, as per the GridSearchCV given below.

# %%
dtree1.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
grid_search_train = GridSearchCV(estimator=dtree1, param_grid=param_grid, n_jobs=1,cv=5)
grid_search_train.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 360 fits failed out of a total of 1440.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
grid_search_train.best_params_ # The best parameters.
# Out:
# {'criterion': 'absolute_error',
#  'max_depth': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
dtree1= DecisionTreeRegressor(criterion='absolute_error',max_depth=5,min_samples_leaf=1,min_samples_split=2, random_state = 42)
# applied the Best Hyperparameter, as per the GridSearchCV given above.

# %%
dtree1.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_depth=5, random_state=42)

# %%
y_pred_train_tuned = dtree1.predict(x_train)

# %% [markdown]
# ### Testing Dataset

# %%
# I am doing Hyperparameter Tuning also.

# %%
param_grid = {'criterion': ['squared_error','friedman_mse','absolute_error','poisson'],'max_depth': [1,2, 3, 4, 5, None],'min_samples_split': [2, 5, 10],'min_samples_leaf': [1, 2, 4]}

# %%
# Training the Model : 80% data

# %%
dtree2= DecisionTreeRegressor(criterion='squared_error',max_depth=2,min_samples_leaf=1,min_samples_split=2, random_state = 42)
# applied the Best Hyperparameter, as per the GridSearchCV given below.

# %%
dtree2.fit(x_test, y_test)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
grid_search_test = GridSearchCV(estimator=dtree2, param_grid=param_grid, n_jobs=1,cv=5)
grid_search_test.fit(x_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
# ...

# %%
grid_search_test.best_params_ # The best parameters.
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 1,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
dtree2= DecisionTreeRegressor(criterion='squared_error',max_depth=1,min_samples_leaf=1,min_samples_split=2,random_state = 42)
# applied the Best Hyperparameter, as per the GridSearchCV given below.

# %%
from sklearn import tree

# %%
x_train_col= x_train.columns

# %%
dtree2.fit(x_test,y_test)
# Out:
# DecisionTreeRegressor(max_depth=1, random_state=42)

# %%
y_pred_test_tuned = dtree2.predict(x_test)

# %% [markdown]
# ## Evaluation - Tuned Dataset

# %%
r2_score_train_tuned=r2_score(y_pred_train_tuned, y_train)

print(f"R2-score - Train - Tuned dataset : {r2_score_train_tuned:.5f}")


r2_score_test_tuned=r2_score(y_pred_test_tuned, y_test)

print(f"R2-score - Test - Tuned dataset : {r2_score_test_tuned:.6f}")
# Out:
# R2-score - Train - Tuned dataset : 0.99957
# R2-score - Test - Tuned dataset : 0.836688

# %% [markdown]
# ## Model building & Tree visualization

# %%
dtree1.fit(x_train, y_train)
plt.figure(figsize=(30,30))
tree.plot_tree(dtree1, feature_names=x_train_col)
plt.show()
# The Tree for training data is given below:-

# %%
x_train.columns
# Out:
# Index(['Natural_disasters', 'Exports', 'Imports', 'FDI', 'Population',
#        'Investment_in_Defence_year_wise',
#        'political_leadership_change_Ariel Sharon',
#        'political_leadership_change_Benjamin Netanyahu',
#        'political_leadership_change_Ehud Barak',
#        'political_leadership_change_Ehud Olmert',
#        'political_leadership_change_Menachem Begin',
#        'political_leadership_change_Naftali Bennett',
#        'political_leadership_change_Shimon Peres',
#        'political_leadership_change_Yair Lapid',
#        'political_leadership_change_Yitzhak Rabin',
#        'political_leadership_change_Yitzḥak Shamir', 'Wars_fought_in_year_No',
#        'Wars_fought_in_year_Yes'],
#       dtype='object')

# %% [markdown]
# ## Significant features

# %%
# Get feature names and importance
features = dtree1.feature_names_in_
importances = dtree1.feature_importances_

for name, score in zip(features, importances):
    print(f"{name}: {score:.5f}")
# Out:
# Natural_disasters: 0.01502
# Exports: 0.19054
# Imports: 0.16181
# FDI: 0.02431
# Population: 0.50940
# Investment_in_Defence_year_wise: 0.07239
# political_leadership_change_Ariel Sharon: 0.00000
# political_leadership_change_Benjamin Netanyahu: 0.00000
# political_leadership_change_Ehud Barak: 0.00000
# political_leadership_change_Ehud Olmert: 0.01588
# political_leadership_change_Menachem Begin: 0.00000
# political_leadership_change_Naftali Bennett: 0.00000
# political_leadership_change_Shimon Peres: 0.00000
# political_leadership_change_Yair Lapid: 0.00000
# political_leadership_change_Yitzhak Rabin: 0.00000
# political_leadership_change_Yitzḥak Shamir: 0.00378
# Wars_fought_in_year_No: 0.00494
# Wars_fought_in_year_Yes: 0.00193
